# %% [markdown]
# # MSDS 430 Mini Project 2

# %% [markdown]
# #### In this assignment you will complete the following exercises and submit your notebook (ipynb file) to Canvas. Your file should include all output, i.e. run each cell and save your file before submitting.

# %% [markdown]
# <font color=green> In this second mini project we begin working with another Python library that is used quite often in data science, Pandas. Pandas provides us with more extensive ways to work with data as multidimensional array objects. As you read through the Pandas documentation, you are encouraged to explore other capabilities beyond what is required for this assignment. You will want to try to expand your knowledge by exploring the Pandas documentation to learn more about the possibilities for future reference. In this assignment you will be reading in some data using Pandas and providing information related to that data. </font>

# %% [markdown]
# Step 1: Use pandas to read the file Employee_Data.xlsx.

# %%
import pandas as pd
df = pd.read_excel('Employee_Data.xlsx')

# %% [markdown]
# Step 2: Inspect the data by printing the first five rows and the last five rows in the dataframe.

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# 0          ...                                  1            80
# 1          ...                                  4            80
# 2          ...                                  2            80
# 3          ...                                  3            80
# 4          ...                                  4            80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                  8                      0               1
# 1                 1                 10                      3               3
# 2                 0                  7                      3               3
# 3                 0                  8                      3               3
# 4                 1                  6                      3               3
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                  4                        0
# 1              10                  7                        1
# 2               0                  0                        0
# 3               8                  7                        3
# 4               2                  2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
df.tail(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber          ...           RelationshipSatisfaction  \
# 1465            2061          ...                                  3
# 1466            2062          ...                                  1
# 1467            2064          ...                                  2
# 1468            2065          ...                                  4
# 1469            2068          ...                                  1
#
#      StandardHours  StockOptionLevel  TotalWorkingYears  \
# 1465            80                 1                 17
# 1466            80                 1                  9
# 1467            80                 1                  6
# 1468            80                 0                 17
# 1469            80                 0                  6
#
#       TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 1465                      3               3               5
# 1466                      5               3               7
# 1467                      0               3               6
# 1468                      3               2               9
# 1469                      3               4               4
#
#      YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 1465                  2                        0                     3
# 1466                  7                        1                     7
# 1467                  2                        0                     3
# 1468                  6                        0                     8
# 1469                  3                        1                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# Step 3: Display the 5 employees who have been at the company the longest in descending order.

# %%
df.nlargest(5, 'TotalWorkingYears')
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 126   58       Yes  Travel_Rarely        147  Research & Development
# 595   58       Yes  Travel_Rarely        286  Research & Development
# 98    58        No  Travel_Rarely        682                   Sales
# 85    56        No  Travel_Rarely       1400  Research & Development
# 270   55        No  Travel_Rarely        452  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 126                23          4        Medical              1
# 595                 2          4  Life Sciences              1
# 98                 10          4        Medical              1
# 85                  7          3  Life Sciences              1
# 270                 1          3        Medical              1
#
#      EmployeeNumber          ...           RelationshipSatisfaction  \
# 126             165          ...                                  4
# 595             825          ...                                  4
# 98              131          ...                                  3
# 85              112          ...                                  1
# 270             374          ...                                  3
#
#     StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 126            80                 1                 40                      3
# 595            80                 0                 40                      2
# 98             80                 0                 38                      1
# 85             80                 0                 37                      3
# 270            80                 0                 37                      2
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 126               2              40                 10
# 595               3              31                 15
# 98                2              37                 10
# 85                2               6                  4
# 270               3              36                 10
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 126                       15                     6
# 595                       13                     8
# 98                         1                     8
# 85                         0                     2
# 270                        4                    13
#
# [5 rows x 35 columns]

# %% [markdown]
# Step 4: Create a new panda series with employee number as the index and job satisfaction as the data. The categories for job satisfaction are 1 = Low, 2 = Medium, 3 = High, 4 = Very High. Inspect your series by displaying the first four records.

# %%
employee_num = df['EmployeeNumber']
job_sat = df['JobSatisfaction']
job_sat_series = pd.Series(data=job_sat, index=employee_num)
job_sat_series[:4]
# Out:
# EmployeeNumber
# 1    2.0
# 2    3.0
# 4    2.0
# 5    4.0
# Name: JobSatisfaction, dtype: float64

# %% [markdown]
# Step 5: Summarize job satisfaction for the company by displaying the number of employees in each category.

# %%
sat_counts = job_sat.value_counts()
df1 = sat_counts.rename_axis('JobSatisfaction').reset_index(name='Count')
df1 = df1.sort_values(by = 'JobSatisfaction')
print (df1)
# Out:
#    JobSatisfaction  Count
# 2                1    289
# 3                2    280
# 1                3    442
# 0                4    459

# %% [markdown]
# Step 6: Display the percentages in each category.

# %%
percent = (job_sat.value_counts(normalize=True))*100
df2 = percent.rename_axis('JobSatisfaction').reset_index(name='Percent')
df2 = df2.sort_values(by = 'JobSatisfaction')
print (df2)
# Out:
#    JobSatisfaction    Percent
# 2                1  19.659864
# 3                2  19.047619
# 1                3  30.068027
# 0                4  31.224490

# %% [markdown]
# Step 7: Create a bar plot of the numbers from Step 5

# %%
import matplotlib.pyplot as plt
plt.bar(df1['JobSatisfaction'], df1['Count'])
plt.title("Job Satisfaction by Number of Employees")
plt.xlabel("Job Satisfaction Score")
plt.ylabel("Number of Employees")
plt.show()
